# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read csv
df = pd.read_csv("Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State.csv")
df
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 0      02/24/2021  01/01/2020  02/20/2021  By Total     NaN    NaN
# 1      02/24/2021  01/01/2020  02/20/2021  By Total     NaN    NaN
# 2      02/24/2021  01/01/2020  02/20/2021  By Total     NaN    NaN
# 3      02/24/2021  01/01/2020  02/20/2021  By Total     NaN    NaN
# 4      02/24/2021  01/01/2020  02/20/2021  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 46813  02/24/2021  02/01/2021  02/20/2021  By Month  2021.0    2.0
# 46814  02/24/2021  02/01/2021  02/20/2021  By Month  2021.0    2.0
# 46815  02/24/2021  02/01/2021  02/20/2021  By Month  2021.0    2.0
# 46816  02/24/2021  02/01/2021  02/20/2021  By Month  2021.0    2.0
# 46817  02/24/2021  02/01/2021  02/20/2021  By Month  2021.0    2.0
#
#                State        Sex          Age Group  COVID-19 Deaths  \
# 0      United States  All Sexes           All Ages         478912.0
# ...

# %%
# Drop redundant rows to look at only ages
df_rows = df[ (df["Group"] == "By Total") & (df["State"] == "United States") & (df["Sex"] == "All Sexes") ]
df_rows
# Out:
#     Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 1   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 2   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 3   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 4   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 5   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 6   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 7   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 8   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 9   02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# 10  02/24/2021  01/01/2020  02/20/2021  By Total   NaN    NaN  United States
# ...

# %%
# Drop columns to look at only ages and deaths
df_age = df_rows[["Age Group", "COVID-19 Deaths"]]
df_age
# Out:
#             Age Group  COVID-19 Deaths
# 0            All Ages         478912.0
# 1        Under 1 year             45.0
# 2          0-17 years            204.0
# 3           1-4 years             24.0
# 4          5-14 years             75.0
# 5         15-24 years            684.0
# 6         18-29 years           1684.0
# 7         25-34 years           3037.0
# 8         30-39 years           5030.0
# 9         35-44 years           8002.0
# 10        40-49 years          13482.0
# 11        45-54 years          22170.0
# 12        50-64 years          70160.0
# 13        55-64 years          56523.0
# 14        65-74 years         103451.0
# 15        75-84 years         133557.0
# 16  85 years and over         151344.0

# %%
# Basic bar graph of deaths by age group including ALL additional groups 
x = df_age["Age Group"]
y = df_age["COVID-19 Deaths"]

plt.bar(x,y)
plt.title("COVID-19 Deaths by Age Group")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
# Same as above without the total deaths group
plt.bar(x[1:], y[1:])
plt.title("COVID-19 Deaths by Age Group")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
# Line graph of deaths by age group including additional groups (contains overlapping groups, total higher than actual)
plt.plot(x[1:], y[1:], marker='o', color='coral')
plt.title("COVID-19 Deaths by Age Group (All Categories)")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
plt.grid()

# %%
# Drop additional groups to get continuous groups without overlap
additional = [0, 2, 6, 8, 10, 12]
df_age_cont = df_age.drop(additional)
df_age_cont
# Out:
#             Age Group  COVID-19 Deaths
# 1        Under 1 year             45.0
# 3           1-4 years             24.0
# 4          5-14 years             75.0
# 5         15-24 years            684.0
# 7         25-34 years           3037.0
# 9         35-44 years           8002.0
# 11        45-54 years          22170.0
# 13        55-64 years          56523.0
# 14        65-74 years         103451.0
# 15        75-84 years         133557.0
# 16  85 years and over         151344.0

# %%
# Continuous line graph of deaths by age group (The Gem)
x = df_age_cont["Age Group"]
y = df_age_cont["COVID-19 Deaths"]

plt.plot(x,y, marker='o', color='coral')
plt.title("COVID-19 Deaths by Age Group")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
plt.grid()

# %%
# Cumulative Deaths (way larger than largest number of deaths in any age group, throws off scale)
yvals = y.tolist()
cumu = [0]
for i in range(len(yvals)):
    cumu.append(yvals[i] + cumu[i])
cumu.pop(0)
# Out:
# 0

# %%
# Continuous and Cumulative not scaled
x = df_age_cont["Age Group"]
y = df_age_cont["COVID-19 Deaths"]

plt.plot(x,cumu, marker='o', color='mistyrose')
plt.plot(x,y, marker='o', color='coral')
plt.title("COVID-19 Deaths by Age Group")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
plt.grid()

# %%
cumu_percent = [val * 100/sum(yvals) for val in cumu]

# %%
# Cumulative by percent
x = df_age_cont["Age Group"]
y = df_age_cont["COVID-19 Deaths"]

plt.plot(x,cumu_percent, marker='o', color='mistyrose')
plt.title("COVID-19 Deaths by Age Group (Cumulative, Percent)")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Percent of Total Deaths")
plt.grid()

# %%
print(cumu_percent)
# Out:
# [0.009396298276092476, 0.01440765735667513, 0.030068154483495924, 0.17289188828010157, 0.8070376186021649, 2.477908258719765, 7.107151209407991, 18.909528264065216, 40.51078277428839, 68.39836963784579, 100.0]

# %%
# Scaled to have total death equal to the largest value in the original plot to keep it on the page
cumu_scaled = [val * max(yvals)/sum(yvals) for val in cumu]

# %%
# Continuous line plot of deaths by age group including cumulative deaths scaled to fit the first continuous graph
x = df_age_cont["Age Group"]
y = df_age_cont["COVID-19 Deaths"]

plt.plot(x,cumu_scaled, marker='o', color='mistyrose')
plt.plot(x,y, marker='o', color='coral')
plt.title("COVID-19 Deaths by Age Group")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
plt.grid()

# %%
# Bar graph of deaths by age groups, including all additional groups (colored lighter) other than total deaths
x = df_age["Age Group"][1:]
y = df_age["COVID-19 Deaths"][1:]

colors = ['mistyrose' if i in additional else 'coral' for i in df_age.index][1:]

plt.bar(x,y, color=colors)
plt.title("COVID-19 Deaths by Age Group (with Aditional Groups)")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %%
# Overlayed Continuous and Cumulative but a little better
x = df_age_cont["Age Group"]
y = df_age_cont["COVID-19 Deaths"]

fig, ax1 = plt.subplots()
plt.title("COVID-19 Deaths by Age Group (Cumulative, Percent)")
plt.xlabel("Age Group")
plt.xticks(rotation = 270)
plt.grid()

ax1.plot(x,y, marker='o', color='coral')
ax1.set_ylabel("Deaths") #, color ='coral'
ax1.tick_params('y') #, colors='coral'

ax2 = ax1.twinx()
ax2.plot(x,cumu_percent, marker='o', color='mistyrose')
ax2.set_ylabel("Percent of Total Deaths") #, color ='mistyrose'

ax1.plot(x,y, marker='o', color='coral')

# %%
tot = sum(df_age_cont["COVID-19 Deaths"].tolist())
multiplier = [num/tot for num in df_age_cont["COVID-19 Deaths"]]
multiplier
# Out:
# [9.396298276092477e-05,
#  5.011359080582654e-05,
#  0.00015660497126820794,
#  0.0014282373379660564,
#  0.0063414573032206335,
#  0.016708706401176,
#  0.04629242950688227,
#  0.11802377054657223,
#  0.21601254510223172,
#  0.27887586863557395,
#  0.31601630362154215]

# %%
# age will be >= bracket
# bracket will be <= age
# Take the biggest bracket your bigger than
brackets = [0, 1, 5, 15, 25, 35, 45, 55, 65, 75, 85]
brackets
# Out:
# [0, 1, 5, 15, 25, 35, 45, 55, 65, 75, 85]

# %%
# 
x = brackets
y = multiplier

plt.plot(x,y, marker='o', color='coral')
plt.title("Vaccine Priority Multiplier by Age Group")
plt.xlabel("Age Group")
#plt.xticks(rotation = 270)
plt.ylabel("Multiplier")
plt.grid()

# %%
# Takes input age, prints custom bracket, mult, and df category  
test_age = 70
decimals = 5
for r in range(len(brackets)):
    print('index:' , r)
    if test_age < brackets[r]:
        print('bracket:' , brackets[r-1] , ',' , 
              'mult:' , round(multiplier[r-1], decimals) , ',' , 
              'df cat:' , df_age_cont["Age Group"].iloc[r-1])
        break
# Out:
# index: 0
# index: 1
# index: 2
# index: 3
# index: 4
# index: 5
# index: 6
# index: 7
# index: 8
# index: 9
# bracket: 65 , mult: 0.21601 , df cat: 65-74 years
